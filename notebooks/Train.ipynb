# %%
# %run -n cnn.py

# %%
ls data/
# Out:
# April_rick_non_overlap.hkl       dataset_february.hkl
# April_tommy_non_overlap.hkl      dataset.hkl
# April_total_non_overlap.hkl      hkl.zip
# August_25_total_non_overlap.hkl  September_1_total_non_overlap.hkl
# August_total_non_overlap.hkl     September_1_total_non_overlap.zip

# %%
dataset = 'September_1_total_non_overlap'

# %%
output_layer, samplers = setup(dataset)
# Out:
# Layer 0 type: <class 'lasagne.layers.input.InputLayer'> output: (32, 3, 70, 70)
# Layer 1 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 32, 68, 68)
# Layer 2 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 32, 66, 66)
# Layer 3 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 32, 64, 64)
# Layer 4 type: <class 'lasagne.layers.dnn.MaxPool2DDNNLayer'> output: (32, 32, 31, 31)
# Layer 5 type: <class 'lasagne.layers.noise.DropoutLayer'> output: (32, 32, 31, 31)
# Layer 6 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 64, 29, 29)
# Layer 7 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 64, 27, 27)
# Layer 8 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 64, 25, 25)
# Layer 9 type: <class 'lasagne.layers.dnn.MaxPool2DDNNLayer'> output: (32, 64, 12, 12)
# Layer 10 type: <class 'lasagne.layers.noise.DropoutLayer'> output: (32, 64, 12, 12)
# Layer 11 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 128, 10, 10)
# Layer 12 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 128, 8, 8)
# Layer 13 type: <class 'lasagne.layers.dnn.Conv2DDNNLayer'> output: (32, 128, 6, 6)
# Layer 14 type: <class 'lasagne.layers.pool.GlobalPoolLayer'> output: (32, 128)
# Layer 15 type: <class 'lasagne.layers.noise.DropoutLayer'> output: (32, 128)
# Layer 16 type: <class 'lasagne.layers.dense.DenseLayer'> output: (32, 10)

# %%
num_epochs = 1
basename = 'september_1'

train(output_layer, samplers, num_epochs, basename)
# Out:
# Learning rate = 0.0001
# Starting training...
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch -1.pickle
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 0.pickle
# Epoch   0/  1 duration 12.6s total 0.2min	 train 2.004 	 val 1.894 	 val acc 27.93%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 1.pickle
# Epoch   1/  1 duration 12.3s total 0.4min	 train 1.684 	 val 1.303 	 val acc 62.21%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 2.pickle
# Epoch   2/  1 duration 12.5s total 0.6min	 train 1.345 	 val 1.096 	 val acc 64.21%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 3.pickle
# Epoch   3/  1 duration 12.3s total 0.8min	 train 1.189 	 val 0.939 	 val acc 70.51%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 4.pickle
# Epoch   4/  1 duration 12.6s total 1.0min	 train 1.045 	 val 0.869 	 val acc 71.00%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 5.pickle
# Epoch   5/  1 duration 12.7s total 1.3min	 train 0.946 	 val 0.804 	 val acc 72.56%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 6.pickle
# Epoch   6/  1 duration 12.5s total 1.5min	 train 0.887 	 val 0.728 	 val acc 73.97%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 7.pickle
# Epoch   7/  1 duration 12.5s total 1.7min	 train 0.835 	 val 0.647 	 val acc 77.88%
# Epoch   8/  1 duration 13.6s total 1.9min	 train 0.821 	 val 0.682 	 val acc 75.20%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 9.pickle
# Epoch   9/  1 duration 12.7s total 2.1min	 train 0.713 	 val 0.625 	 val acc 78.56%
# Epoch  10/  1 duration 12.8s total 2.3min	 train 0.736 	 val 0.634 	 val acc 78.37%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 11.pickle
# Epoch  11/  1 duration 13.1s total 2.5min	 train 0.703 	 val 0.537 	 val acc 81.30%
# Epoch  12/  1 duration 12.9s total 2.8min	 train 0.667 	 val 0.592 	 val acc 77.69%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 13.pickle
# Epoch  13/  1 duration 12.9s total 3.0min	 train 0.631 	 val 0.520 	 val acc 80.66%
# Epoch  14/  1 duration 12.8s total 3.2min	 train 0.608 	 val 0.538 	 val acc 81.98%
# Epoch  15/  1 duration 12.9s total 3.4min	 train 0.590 	 val 0.541 	 val acc 81.69%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 16.pickle
# Epoch  16/  1 duration 13.2s total 3.6min	 train 0.598 	 val 0.427 	 val acc 86.47%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 17.pickle
# Epoch  17/  1 duration 13.0s total 3.8min	 train 0.526 	 val 0.420 	 val acc 87.55%
# Epoch  18/  1 duration 12.8s total 4.0min	 train 0.546 	 val 0.438 	 val acc 85.74%
# Epoch  19/  1 duration 13.0s total 4.3min	 train 0.518 	 val 0.480 	 val acc 85.06%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 20.pickle
# Epoch  20/  1 duration 13.2s total 4.5min	 train 0.528 	 val 0.368 	 val acc 87.35%
# Epoch  21/  1 duration 12.9s total 4.7min	 train 0.498 	 val 0.438 	 val acc 86.52%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 22.pickle
# Epoch  22/  1 duration 13.0s total 4.9min	 train 0.435 	 val 0.363 	 val acc 88.04%
# Epoch  23/  1 duration 13.1s total 5.1min	 train 0.443 	 val 0.372 	 val acc 89.01%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 24.pickle
# Epoch  24/  1 duration 13.2s total 5.3min	 train 0.414 	 val 0.321 	 val acc 90.33%
# Epoch  25/  1 duration 12.8s total 5.6min	 train 0.428 	 val 0.352 	 val acc 88.67%
# Epoch  26/  1 duration 13.1s total 5.8min	 train 0.382 	 val 0.383 	 val acc 88.18%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 27.pickle
# Epoch  27/  1 duration 13.0s total 6.0min	 train 0.403 	 val 0.306 	 val acc 91.60%
# Epoch  28/  1 duration 13.1s total 6.2min	 train 0.367 	 val 0.308 	 val acc 90.23%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 29.pickle
# Epoch  29/  1 duration 13.0s total 6.4min	 train 0.352 	 val 0.301 	 val acc 91.26%
# Epoch  30/  1 duration 12.9s total 6.6min	 train 0.361 	 val 0.336 	 val acc 89.31%
# Epoch  31/  1 duration 12.9s total 6.9min	 train 0.349 	 val 0.326 	 val acc 91.16%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 32.pickle
# Epoch  32/  1 duration 13.0s total 7.1min	 train 0.343 	 val 0.298 	 val acc 90.92%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 33.pickle
# Epoch  33/  1 duration 13.3s total 7.3min	 train 0.325 	 val 0.265 	 val acc 91.41%
# Epoch  34/  1 duration 12.9s total 7.5min	 train 0.349 	 val 0.286 	 val acc 91.36%
# Epoch  35/  1 duration 13.2s total 7.7min	 train 0.288 	 val 0.269 	 val acc 92.53%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 36.pickle
# Epoch  36/  1 duration 13.8s total 8.0min	 train 0.314 	 val 0.251 	 val acc 92.68%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 37.pickle
# Epoch  37/  1 duration 13.2s total 8.2min	 train 0.309 	 val 0.228 	 val acc 92.72%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 38.pickle
# Epoch  38/  1 duration 13.2s total 8.4min	 train 0.312 	 val 0.215 	 val acc 92.82%
# Epoch  39/  1 duration 13.2s total 8.6min	 train 0.288 	 val 0.218 	 val acc 93.41%
# Epoch  40/  1 duration 13.0s total 8.8min	 train 0.299 	 val 0.241 	 val acc 93.46%
# Epoch  41/  1 duration 13.0s total 9.1min	 train 0.293 	 val 0.270 	 val acc 92.09%
# Epoch  42/  1 duration 13.3s total 9.3min	 train 0.272 	 val 0.229 	 val acc 92.87%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 43.pickle
# Epoch  43/  1 duration 13.1s total 9.5min	 train 0.277 	 val 0.211 	 val acc 93.90%
# Epoch  44/  1 duration 13.0s total 9.7min	 train 0.253 	 val 0.246 	 val acc 93.51%
# Epoch  45/  1 duration 13.2s total 9.9min	 train 0.243 	 val 0.224 	 val acc 93.90%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 46.pickle
# Epoch  46/  1 duration 13.1s total 10.2min	 train 0.253 	 val 0.197 	 val acc 93.95%
# Epoch  47/  1 duration 13.0s total 10.4min	 train 0.265 	 val 0.210 	 val acc 93.70%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 48.pickle
# Epoch  48/  1 duration 13.3s total 10.6min	 train 0.249 	 val 0.189 	 val acc 94.68%
# Epoch  49/  1 duration 13.0s total 10.8min	 train 0.226 	 val 0.249 	 val acc 93.07%
# Epoch  50/  1 duration 12.9s total 11.0min	 train 0.227 	 val 0.215 	 val acc 93.36%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 51.pickle
# Epoch  51/  1 duration 13.3s total 11.2min	 train 0.258 	 val 0.181 	 val acc 94.04%
# Epoch  52/  1 duration 12.9s total 11.5min	 train 0.242 	 val 0.187 	 val acc 93.80%
# Epoch  53/  1 duration 13.2s total 11.7min	 train 0.253 	 val 0.253 	 val acc 92.24%
# Epoch  54/  1 duration 13.3s total 11.9min	 train 0.221 	 val 0.197 	 val acc 94.29%
# Epoch  55/  1 duration 13.1s total 12.1min	 train 0.211 	 val 0.244 	 val acc 93.60%
# Epoch  56/  1 duration 13.0s total 12.3min	 train 0.221 	 val 0.184 	 val acc 94.09%
# Epoch  57/  1 duration 13.3s total 12.6min	 train 0.236 	 val 0.202 	 val acc 94.34%
# Epoch  58/  1 duration 13.0s total 12.8min	 train 0.230 	 val 0.222 	 val acc 93.51%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 59.pickle
# Epoch  59/  1 duration 13.4s total 13.0min	 train 0.219 	 val 0.176 	 val acc 94.87%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 60.pickle
# Epoch  60/  1 duration 13.1s total 13.2min	 train 0.211 	 val 0.161 	 val acc 96.04%
# Epoch  61/  1 duration 13.2s total 13.4min	 train 0.205 	 val 0.196 	 val acc 94.24%
# Epoch  62/  1 duration 13.2s total 13.7min	 train 0.197 	 val 0.188 	 val acc 94.09%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 63.pickle
# Epoch  63/  1 duration 13.1s total 13.9min	 train 0.209 	 val 0.161 	 val acc 94.92%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 64.pickle
# Epoch  64/  1 duration 13.1s total 14.1min	 train 0.212 	 val 0.148 	 val acc 95.12%
# Epoch  65/  1 duration 13.3s total 14.3min	 train 0.168 	 val 0.173 	 val acc 95.36%
# Epoch  66/  1 duration 13.0s total 14.5min	 train 0.190 	 val 0.216 	 val acc 93.80%
# Epoch  67/  1 duration 13.2s total 14.8min	 train 0.192 	 val 0.194 	 val acc 94.53%
# Epoch  68/  1 duration 13.3s total 15.0min	 train 0.200 	 val 0.197 	 val acc 94.53%
# Epoch  69/  1 duration 13.0s total 15.2min	 train 0.179 	 val 0.183 	 val acc 94.87%
# Epoch  70/  1 duration 13.1s total 15.4min	 train 0.177 	 val 0.165 	 val acc 94.38%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 71.pickle
# Epoch  71/  1 duration 13.1s total 15.6min	 train 0.191 	 val 0.122 	 val acc 95.85%
# Epoch  72/  1 duration 13.2s total 15.8min	 train 0.179 	 val 0.162 	 val acc 94.73%
# Epoch  73/  1 duration 13.0s total 16.1min	 train 0.193 	 val 0.146 	 val acc 95.85%
# Epoch  74/  1 duration 13.0s total 16.3min	 train 0.163 	 val 0.168 	 val acc 94.58%
# Epoch  75/  1 duration 13.3s total 16.5min	 train 0.182 	 val 0.156 	 val acc 95.70%
# Epoch  76/  1 duration 13.0s total 16.7min	 train 0.172 	 val 0.166 	 val acc 94.97%
# Epoch  77/  1 duration 13.3s total 16.9min	 train 0.187 	 val 0.142 	 val acc 95.46%
# Epoch  78/  1 duration 13.0s total 17.2min	 train 0.186 	 val 0.131 	 val acc 95.51%
# Epoch  79/  1 duration 13.3s total 17.4min	 train 0.181 	 val 0.162 	 val acc 94.92%
# Epoch  80/  1 duration 13.0s total 17.6min	 train 0.146 	 val 0.184 	 val acc 93.90%
# Epoch  81/  1 duration 13.0s total 17.8min	 train 0.154 	 val 0.141 	 val acc 95.70%
# Epoch  82/  1 duration 13.3s total 18.0min	 train 0.171 	 val 0.186 	 val acc 94.87%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 83.pickle
# Epoch  83/  1 duration 13.2s total 18.3min	 train 0.180 	 val 0.121 	 val acc 96.39%
# Epoch  84/  1 duration 13.0s total 18.5min	 train 0.165 	 val 0.165 	 val acc 94.82%
# Epoch  85/  1 duration 13.3s total 18.7min	 train 0.148 	 val 0.141 	 val acc 96.14%
# Epoch  86/  1 duration 13.1s total 18.9min	 train 0.151 	 val 0.157 	 val acc 95.36%
# Epoch  87/  1 duration 13.1s total 19.1min	 train 0.159 	 val 0.132 	 val acc 96.04%
# Epoch  88/  1 duration 13.0s total 19.3min	 train 0.154 	 val 0.153 	 val acc 96.09%
# Epoch  89/  1 duration 13.2s total 19.6min	 train 0.154 	 val 0.193 	 val acc 94.92%
# Epoch  90/  1 duration 13.0s total 19.8min	 train 0.146 	 val 0.128 	 val acc 96.34%
# Epoch  91/  1 duration 13.0s total 20.0min	 train 0.159 	 val 0.169 	 val acc 96.78%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 92.pickle
# Epoch  92/  1 duration 13.1s total 20.2min	 train 0.151 	 val 0.111 	 val acc 96.48%
# Epoch  93/  1 duration 13.3s total 20.4min	 train 0.160 	 val 0.134 	 val acc 96.48%
# Epoch  94/  1 duration 13.0s total 20.7min	 train 0.155 	 val 0.124 	 val acc 96.09%
# Epoch  95/  1 duration 13.3s total 20.9min	 train 0.143 	 val 0.140 	 val acc 95.65%
# Epoch  96/  1 duration 13.0s total 21.1min	 train 0.147 	 val 0.128 	 val acc 96.00%
# Epoch  97/  1 duration 13.3s total 21.3min	 train 0.156 	 val 0.161 	 val acc 95.85%
# Epoch  98/  1 duration 13.1s total 21.5min	 train 0.146 	 val 0.117 	 val acc 96.73%
# Epoch  99/  1 duration 13.3s total 21.8min	 train 0.159 	 val 0.139 	 val acc 96.00%
# Epoch 100/  1 duration 13.1s total 22.0min	 train 0.152 	 val 0.132 	 val acc 96.24%
# Epoch 101/  1 duration 13.1s total 22.2min	 train 0.154 	 val 0.135 	 val acc 96.58%
# Epoch 102/  1 duration 13.3s total 22.4min	 train 0.143 	 val 0.191 	 val acc 94.87%
# Epoch 103/  1 duration 13.1s total 22.6min	 train 0.131 	 val 0.159 	 val acc 96.68%
# Epoch 104/  1 duration 13.3s total 22.9min	 train 0.144 	 val 0.157 	 val acc 95.51%
# Epoch 105/  1 duration 13.1s total 23.1min	 train 0.132 	 val 0.154 	 val acc 95.65%
# Epoch 106/  1 duration 14.4s total 23.3min	 train 0.128 	 val 0.141 	 val acc 96.48%
# Epoch 107/  1 duration 14.0s total 23.5min	 train 0.146 	 val 0.143 	 val acc 95.90%
# Epoch 108/  1 duration 13.9s total 23.8min	 train 0.144 	 val 0.146 	 val acc 95.61%
# Epoch 109/  1 duration 13.7s total 24.0min	 train 0.137 	 val 0.139 	 val acc 95.80%
# Epoch 110/  1 duration 13.8s total 24.2min	 train 0.147 	 val 0.125 	 val acc 96.44%
# Epoch 111/  1 duration 14.3s total 24.5min	 train 0.137 	 val 0.154 	 val acc 95.61%
# Epoch 112/  1 duration 14.1s total 24.7min	 train 0.124 	 val 0.141 	 val acc 95.85%
# Epoch 113/  1 duration 14.1s total 24.9min	 train 0.137 	 val 0.133 	 val acc 96.00%
# Epoch 114/  1 duration 13.1s total 25.2min	 train 0.141 	 val 0.127 	 val acc 95.85%
# Epoch 115/  1 duration 13.0s total 25.4min	 train 0.124 	 val 0.113 	 val acc 96.53%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 116.pickle
# Epoch 116/  1 duration 13.3s total 25.6min	 train 0.139 	 val 0.100 	 val acc 97.17%
# Epoch 117/  1 duration 13.4s total 25.8min	 train 0.142 	 val 0.137 	 val acc 96.29%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 118.pickle
# Epoch 118/  1 duration 13.2s total 26.0min	 train 0.137 	 val 0.096 	 val acc 96.97%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 119.pickle
# Epoch 119/  1 duration 13.2s total 26.3min	 train 0.129 	 val 0.086 	 val acc 97.36%
# Epoch 120/  1 duration 13.3s total 26.5min	 train 0.127 	 val 0.134 	 val acc 96.24%
# Epoch 121/  1 duration 14.1s total 26.7min	 train 0.129 	 val 0.130 	 val acc 96.19%
# Epoch 122/  1 duration 13.0s total 26.9min	 train 0.128 	 val 0.131 	 val acc 96.83%
# Epoch 123/  1 duration 13.0s total 27.2min	 train 0.133 	 val 0.140 	 val acc 96.29%
# Epoch 124/  1 duration 13.2s total 27.4min	 train 0.129 	 val 0.105 	 val acc 96.53%
# Epoch 125/  1 duration 13.0s total 27.6min	 train 0.116 	 val 0.162 	 val acc 95.12%
# Epoch 126/  1 duration 13.5s total 27.8min	 train 0.132 	 val 0.141 	 val acc 96.39%
# Epoch 127/  1 duration 13.0s total 28.0min	 train 0.117 	 val 0.154 	 val acc 96.48%
# Epoch 128/  1 duration 13.1s total 28.3min	 train 0.138 	 val 0.122 	 val acc 96.78%
# Epoch 129/  1 duration 13.4s total 28.5min	 train 0.117 	 val 0.108 	 val acc 96.58%
# Epoch 130/  1 duration 13.5s total 28.7min	 train 0.116 	 val 0.115 	 val acc 96.58%
# Epoch 131/  1 duration 13.8s total 28.9min	 train 0.113 	 val 0.105 	 val acc 96.78%
# Epoch 132/  1 duration 13.4s total 29.2min	 train 0.116 	 val 0.139 	 val acc 95.17%
# Epoch 133/  1 duration 13.0s total 29.4min	 train 0.111 	 val 0.149 	 val acc 96.09%
# Epoch 134/  1 duration 13.3s total 29.6min	 train 0.118 	 val 0.107 	 val acc 96.63%
# Epoch 135/  1 duration 13.1s total 29.8min	 train 0.113 	 val 0.129 	 val acc 96.53%
# Epoch 136/  1 duration 13.6s total 30.0min	 train 0.131 	 val 0.132 	 val acc 96.58%
# Epoch 137/  1 duration 13.4s total 30.3min	 train 0.107 	 val 0.144 	 val acc 95.95%
# Epoch 138/  1 duration 13.6s total 30.5min	 train 0.116 	 val 0.119 	 val acc 96.19%
# Epoch 139/  1 duration 13.4s total 30.7min	 train 0.116 	 val 0.124 	 val acc 96.68%
# Epoch 140/  1 duration 13.7s total 30.9min	 train 0.124 	 val 0.115 	 val acc 96.83%
# Epoch 141/  1 duration 13.5s total 31.2min	 train 0.107 	 val 0.113 	 val acc 97.07%
# Epoch 142/  1 duration 13.7s total 31.4min	 train 0.113 	 val 0.117 	 val acc 96.53%
# Epoch 143/  1 duration 13.5s total 31.6min	 train 0.093 	 val 0.127 	 val acc 96.48%
# Epoch 144/  1 duration 13.5s total 31.8min	 train 0.108 	 val 0.153 	 val acc 95.21%
# Epoch 145/  1 duration 13.4s total 32.1min	 train 0.112 	 val 0.106 	 val acc 97.22%
# Epoch 146/  1 duration 13.7s total 32.3min	 train 0.108 	 val 0.127 	 val acc 96.04%
# Epoch 147/  1 duration 13.5s total 32.5min	 train 0.111 	 val 0.162 	 val acc 96.14%
# Epoch 148/  1 duration 13.5s total 32.7min	 train 0.096 	 val 0.166 	 val acc 96.00%
# Decreased learning rate to 1e-05
# Epoch 149/  1 duration 13.8s total 33.0min	 train 0.110 	 val 0.146 	 val acc 96.44%
# Epoch 150/  1 duration 13.5s total 33.2min	 train 0.107 	 val 0.148 	 val acc 96.00%
# Epoch 151/  1 duration 13.7s total 33.4min	 train 0.120 	 val 0.112 	 val acc 96.97%
# Epoch 152/  1 duration 13.5s total 33.6min	 train 0.107 	 val 0.121 	 val acc 96.39%
# Epoch 153/  1 duration 13.7s total 33.9min	 train 0.098 	 val 0.141 	 val acc 96.39%
# Epoch 154/  1 duration 13.5s total 34.1min	 train 0.104 	 val 0.096 	 val acc 97.17%
# Epoch 155/  1 duration 13.8s total 34.3min	 train 0.097 	 val 0.149 	 val acc 96.00%
# Epoch 156/  1 duration 13.6s total 34.6min	 train 0.105 	 val 0.132 	 val acc 96.00%
# Epoch 157/  1 duration 13.7s total 34.8min	 train 0.105 	 val 0.110 	 val acc 96.88%
# Epoch 158/  1 duration 13.6s total 35.0min	 train 0.116 	 val 0.109 	 val acc 95.70%
# Epoch 159/  1 duration 13.7s total 35.2min	 train 0.104 	 val 0.169 	 val acc 95.21%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 160.pickle
# Epoch 160/  1 duration 13.9s total 35.5min	 train 0.105 	 val 0.084 	 val acc 96.92%
# Epoch 161/  1 duration 13.6s total 35.7min	 train 0.113 	 val 0.099 	 val acc 96.78%
# Epoch 162/  1 duration 13.6s total 35.9min	 train 0.108 	 val 0.105 	 val acc 96.78%
# Epoch 163/  1 duration 13.6s total 36.2min	 train 0.096 	 val 0.115 	 val acc 96.92%
# Epoch 164/  1 duration 13.7s total 36.4min	 train 0.099 	 val 0.102 	 val acc 97.61%
# Epoch 165/  1 duration 13.6s total 36.6min	 train 0.109 	 val 0.104 	 val acc 97.41%
# Epoch 166/  1 duration 13.6s total 36.8min	 train 0.103 	 val 0.109 	 val acc 96.83%
# Epoch 167/  1 duration 13.6s total 37.1min	 train 0.090 	 val 0.102 	 val acc 97.46%
# Epoch 168/  1 duration 13.8s total 37.3min	 train 0.097 	 val 0.186 	 val acc 96.09%
# Epoch 169/  1 duration 13.8s total 37.5min	 train 0.090 	 val 0.102 	 val acc 97.71%
# Epoch 170/  1 duration 13.5s total 37.7min	 train 0.096 	 val 0.129 	 val acc 96.88%
# Epoch 171/  1 duration 13.5s total 38.0min	 train 0.093 	 val 0.110 	 val acc 97.02%
# Epoch 172/  1 duration 13.8s total 38.2min	 train 0.095 	 val 0.172 	 val acc 96.00%
# Epoch 173/  1 duration 13.5s total 38.4min	 train 0.086 	 val 0.113 	 val acc 96.48%
# Epoch 174/  1 duration 13.3s total 38.6min	 train 0.095 	 val 0.110 	 val acc 96.58%
# Saved network parameters to /home/eben/projects/rbc_cnn/output/models/september_1 epoch 175.pickle
# Epoch 175/  1 duration 13.1s total 38.9min	 train 0.101 	 val 0.076 	 val acc 97.17%
# Epoch 176/  1 duration 13.8s total 39.1min	 train 0.091 	 val 0.129 	 val acc 97.02%
# Epoch 177/  1 duration 13.9s total 39.3min	 train 0.077 	 val 0.174 	 val acc 96.19%
# Epoch 178/  1 duration 13.4s total 39.6min	 train 0.099 	 val 0.108 	 val acc 96.97%
# Epoch 179/  1 duration 13.9s total 39.8min	 train 0.086 	 val 0.084 	 val acc 97.61%
# Epoch 180/  1 duration 13.6s total 40.0min	 train 0.089 	 val 0.087 	 val acc 97.41%
# Epoch 181/  1 duration 13.7s total 40.2min	 train 0.088 	 val 0.111 	 val acc 96.73%
# Epoch 182/  1 duration 14.0s total 40.5min	 train 0.087 	 val 0.092 	 val acc 96.83%
# Epoch 183/  1 duration 13.7s total 40.7min	 train 0.102 	 val 0.130 	 val acc 96.63%
# Epoch 184/  1 duration 13.7s total 40.9min	 train 0.099 	 val 0.118 	 val acc 96.48%
# Epoch 185/  1 duration 13.9s total 41.2min	 train 0.089 	 val 0.127 	 val acc 96.58%
# Epoch 186/  1 duration 13.7s total 41.4min	 train 0.097 	 val 0.109 	 val acc 96.83%
# Epoch 187/  1 duration 13.7s total 41.6min	 train 0.098 	 val 0.139 	 val acc 96.39%
# Epoch 188/  1 duration 14.0s total 41.8min	 train 0.086 	 val 0.130 	 val acc 96.34%
# Epoch 189/  1 duration 13.7s total 42.1min	 train 0.096 	 val 0.141 	 val acc 96.24%
# Epoch 190/  1 duration 13.9s total 42.3min	 train 0.102 	 val 0.151 	 val acc 96.92%
# Epoch 191/  1 duration 13.7s total 42.5min	 train 0.088 	 val 0.099 	 val acc 97.17%
# Epoch 192/  1 duration 13.6s total 42.8min	 train 0.105 	 val 0.115 	 val acc 96.68%
# Epoch 193/  1 duration 13.6s total 43.0min	 train 0.089 	 val 0.136 	 val acc 96.39%
# Epoch 194/  1 duration 13.6s total 43.2min	 train 0.087 	 val 0.119 	 val acc 96.63%
# Epoch 195/  1 duration 13.6s total 43.4min	 train 0.097 	 val 0.117 	 val acc 96.44%
# Epoch 196/  1 duration 13.9s total 43.7min	 train 0.093 	 val 0.083 	 val acc 97.02%
# Epoch 197/  1 duration 13.0s total 43.9min	 train 0.100 	 val 0.106 	 val acc 96.78%
# Epoch 198/  1 duration 13.0s total 44.1min	 train 0.093 	 val 0.101 	 val acc 97.51%
# Epoch 199/  1 duration 13.0s total 44.3min	 train 0.083 	 val 0.106 	 val acc 96.78%
# Epoch 200/  1 duration 12.9s total 44.5min	 train 0.097 	 val 0.107 	 val acc 97.41%
# Epoch 201/  1 duration 12.9s total 44.8min	 train 0.104 	 val 0.103 	 val acc 97.36%
# Epoch 202/  1 duration 13.2s total 45.0min	 train 0.100 	 val 0.121 	 val acc 97.22%
# Epoch 203/  1 duration 12.9s total 45.2min	 train 0.089 	 val 0.081 	 val acc 97.27%
# Epoch 204/  1 duration 13.2s total 45.4min	 train 0.090 	 val 0.077 	 val acc 97.61%
# Decreased learning rate to 1e-06
# Epoch 205/  1 duration 13.0s total 45.6min	 train 0.087 	 val 0.129 	 val acc 96.97%
# Epoch 206/  1 duration 13.0s total 45.8min	 train 0.091 	 val 0.085 	 val acc 97.51%
# Epoch 207/  1 duration 12.9s total 46.1min	 train 0.089 	 val 0.124 	 val acc 96.48%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2654f011f2ca> in <module>()
#       2 basename = 'september_1'
#       3
# ----> 4 train(output_layer, samplers, num_epochs, basename)
#
# /home/eben/projects/rbc_cnn/cnn.py in train(output_layer, samplers, num_epochs, basename)
#     423             output_layer,
#     424             X_tensor_type=T.tensor4,
# --> 425             learning_rate=learning_rate,
#     426         )
#     427         epoch = train_epoch(iter_funcs, dataset)
#
# /home/eben/projects/rbc_cnn/cnn.py in create_iter_functions(dataset, output_layer, X_tensor_type, batch_size, learning_rate, momentum)
#     283     iter_train = theano.function(
#     284         [X_batch, y_batch], loss_train,
# --> 285         updates=updates,
#     286     )
#     287
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     320                    on_unused_input=on_unused_input,
#     321                    profile=profile,
# --> 322                    output_keys=output_keys)
#     323     # We need to add the flag check_aliased inputs if we have any mutable or
#     324     # borrowed used defined inputs
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     478                          accept_inplace=accept_inplace, name=name,
#     479                          profile=profile, on_unused_input=on_unused_input,
# --> 480                          output_keys=output_keys)
#     481
#     482
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1815                    profile=profile,
#    1816                    on_unused_input=on_unused_input,
# -> 1817                    output_keys=output_keys).create(
#    1818             defaults)
#    1819
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1495                         optimizer, inputs, outputs)
#    1496                 else:
# -> 1497                     optimizer_profile = optimizer(fgraph)
#    1498
#    1499                 end_optimizer = time.time()
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/gof/opt.pyc in __call__(self, fgraph)
#     100
#     101         """
# --> 102         return self.optimize(fgraph)
#     103
#     104     def add_requirements(self, fgraph):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      88             orig = theano.tensor.basic.constant.enable
#      89             theano.tensor.basic.constant.enable = False
# ---> 90             ret = self.apply(fgraph, *args, **kwargs)
#      91         finally:
#      92             theano.tensor.basic.constant.enable = orig
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/gof/opt.pyc in apply(self, fgraph)
#     229             try:
#     230                 t0 = time.time()
# --> 231                 sub_prof = optimizer.optimize(fgraph)
#     232                 l.append(float(time.time() - t0))
#     233                 sub_profs.append(sub_prof)
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      84
#      85         """
# ---> 86         self.add_requirements(fgraph)
#      87         try:
#      88             orig = theano.tensor.basic.constant.enable
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/opt.pyc in add_requirements(self, fgraph)
#    1413
#    1414     def add_requirements(self, fgraph):
# -> 1415         fgraph.attach_feature(ShapeFeature())
#    1416
#    1417     def apply(self, fgraph):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/gof/fg.pyc in attach_feature(self, feature)
#     558         if attach is not None:
#     559             try:
# --> 560                 attach(self)
#     561             except toolbox.AlreadyThere:
#     562                 return
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/opt.pyc in on_attach(self, fgraph)
#    1237
#    1238         for node in fgraph.toposort():
# -> 1239             self.on_import(fgraph, node, reason='on_attach')
#    1240
#    1241     def on_import(self, fgraph, node, reason):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/opt.pyc in on_import(self, fgraph, node, reason)
#    1290
#    1291         for r, s in izip(node.outputs, o_shapes):
# -> 1292             self.set_shape(r, s)
#    1293
#    1294     def on_change_input(self, fgraph, node, i, r, new_r, reason):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/opt.pyc in set_shape(self, r, s, override)
#    1097                         self.lscalar_one.equals(
#    1098                             T.extract_constant(shape_vars[i]))
# -> 1099                         for i in xrange(r.ndim)])
#    1100             self.shape_of[r] = tuple(shape_vars)
#    1101             for sv in shape_vars:
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/var.pyc in equals(self, other)
#     895             other = theano.tensor.basic.constant(other)
#     896         return (isinstance(other, TensorConstant) and
# --> 897                 self.signature() == other.signature())
#     898
#     899     def __copy__(self):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/var.pyc in __eq__(self, other)
#     805             # False, which is why we do not bother with testing `other.has_nan`
#     806             # here).
# --> 807             return (self.sum == other.sum) and numpy.all(d0 == d1)
#     808
#     809     def __hash__(self):
#
# /home/eben/venv/local/lib/python2.7/site-packages/Theano-0.9.0.dev0-py2.7.egg/theano/tensor/var.pyc in _get_sum(self)
#     815         return hash_from_ndarray(d)
#     816
# --> 817     def _get_sum(self):
#     818         """Compute sum of non NaN / Inf values in the array."""
#     819         try:
#
# KeyboardInterrupt:
