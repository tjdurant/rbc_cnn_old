# %%
import os
import numpy as np
import pandas as pd

from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

DATA_DIR = "C:/Users/thoma/Documents/00GitHub/00_LOCAL_ONLY/rbc_cnn_sync/output/models/"
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode EXPIRED 54 days ago
#
#     Your usage of mkl is now out of compliance with the license agreement.
#     A license for mkl can be purchased at: http://continuum.io

# %%
df = pd.read_pickle(DATA_DIR + 'testrun epoch 111.pickle')

# %%
df
# Out:
# {'meta': {'basename': 'testrun',
#   'epoch': 111,
#   'metrics': {'train': [99,
#     0.37647161,
#     0.27647406,
#     0.27812916,
#     0.26579481,
#     0.26076978,
#     0.25170982,
#     0.24156776,
#     0.24780723,
#     0.23407702,
#     0.25247341,
#     0.23226184,
#     0.24931717,
#     0.24315639,
#     0.24145514,
#     0.24126278,
#     0.23503035,
#     0.25033063,
#     0.23418531,
#     0.21971728,
#     0.24019465,
#     0.22413315,
#     0.2063821,
#     0.22509687,
#     0.20153242,
#     0.22610022,
#     0.22517973,
#     0.20730186,
#     0.20031887,
#     0.18970913,
#     0.18771383,
#     0.194839,
#     0.18773414,
#     0.17670806,
#     0.1817382,
#     0.18280077,
#     0.16639939,
#     0.17720926,
#     0.16432045,
#     0.16019604,
#     0.17835036,
#     0.15495124,
#     0.16441855,
#     0.14979246,
#     0.15605745,
#     0.1597591,
#     0.14879236,
#     0.14122131,
#     0.1390415,
#     0.14707285,
#     0.13878262,
#     0.14808503,
# ...
